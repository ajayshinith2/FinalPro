# %%
import pandas as pd
import xlrd
import seaborn as sns
from IPython.core.debugger import set_trace
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest

# %%
df = pd.read_csv (r'C:\Users\Computer\Desktop\project\dataset\tapioca.csv')    
num=df.shape[0]
del df["crop"]
print(num)
df2 = pd.read_csv (r'C:\Users\Computer\Desktop\project\dataset\carrot.csv')    
del df2["crop"]
# Out:
# 960

# %%
def function(data,data2,i):
    contamination = (2/df.shape[0])
    data["season"][40]=data2["season"][i]
    data["pH"][40]=data2["pH"][i]
    data["soil_type"][40]=data2["soil_type"][i]
    data["elevation"][40]=data2["elevation"][i]
    data["temperature"][40]=data2["temperature"][i]
    model = IsolationForest(contamination=contamination, n_estimators=1000)
    model.fit(data)
    df["iforest"] = pd.Series(model.predict(data))
    df["iforest"] = df["iforest"].map({1: 0, -1: 1})
    c=0
    for i in range (0,num):
    #if(ans[i]==1):
        if(df["iforest"][i]==1):
            return i
            c+=1
    print("the count is : ",c)

# %%
df = pd.read_csv (r'C:\Users\Computer\Desktop\projectDatas\dataset\carrot.csv')    
num=df.shape[0]


df2 = pd.read_csv (r'C:\Users\Computer\Desktop\projectDatas\dataset\chilli.csv') 
num2=df2.shape[0]
df3 = pd.read_csv (r'C:\Users\Computer\Desktop\projectDatas\dataset\cucumber.csv')    
num=df3.shape[0]
df4 = pd.read_csv (r'C:\Users\Computer\Desktop\projectDatas\dataset\onion.csv') 
num2=df4.shape[0]
df5 = pd.read_csv (r'C:\Users\Computer\Desktop\projectDatas\dataset\pepper.csv')    
num=df5.shape[0]

df6 = pd.read_csv (r'C:\Users\Computer\Desktop\projectDatas\dataset\tapioca.csv')    
num=df6.shape[0]
df7 = pd.read_csv (r'C:\Users\Computer\Desktop\projectDatas\dataset\testData1.csv') 
num2=df7.shape[0]


del df["crop"]   
del df2["crop"]
del df3["crop"]   
del df4["crop"]
del df5["crop"]   
del df6["crop"]
#del df7["crop"] 


print(num,num2)
print(df7["crop"][100])
# Out:
# 812 145
# pepper

# %%
print(df7.shape[0])
# Out:
# 145

# %%
data=df.copy()
data = data.dropna()
data2=df2.copy()
data2 = data2.dropna()

data3=df3.copy()
data3 = data3.dropna()
data4=df4.copy()
data4 = data4.dropna()

data5=df5.copy()
data5 = data5.dropna()
data6=df6.copy()
data6 = data6.dropna()

data7=df7.copy()
del data7["crop"]
data7 = data7.dropna()

# %%
ctp,chitp,cucutp,otp,ptp,ttp=0,0,0,0,0,0
falsePrediction=0
for i in range(0,num2):
    ans1=function(data,data7,i)
    if(ans1!=40 and df7['crop'][i]=="carrot"):
        ctp+=1
    if(ans1!=40 and df7['crop'][i]!="carrot"):
        falsePrediction+=1
    ans2=function(data2,data7,i)
    if(ans2!=40 and df7['crop'][i]=="chilli"):
        chitp+=1
    if(ans2!=40 and df7['crop'][i]!="chilli"):
        falsePrediction+=1
    ans3=function(data3,data7,i)
    if(ans3!=40 and df7['crop'][i]=="cucumber"):
        cucutp+=1
    if(ans3!=40 and df7['crop'][i]!="cucumber"):
        falsePrediction+=1
    ans4=function(data4,data7,i)
    if(ans4!=40 and df7['crop'][i]=="onion "):
        otp+=1
    if(ans4!=40 and df7['crop'][i]!="onion "):
        falsePrediction+=1
    ans5=function(data5,data7,i)
    if(ans5!=40 and df7['crop'][i]=="pepper"):
        ptp+=1
    if(ans5!=40 and df7['crop'][i]!="pepper"):
           falsePrediction+=1
        
    ans6=function(data6,data7,i)
    if(ans6!=40 and df7['crop'][i]=="tapioca"):
        ttp+=1
    if(ans6!=40 and df7['crop'][i]!="tapioca"):
        falsePrediction+=1
    #print(ans1)#,ans2,ans3,ans4,ans5)
    #print(ctp)
print("The True positive of carrot is : ",ctp)
print("The True positive of chilli is : ",chitp)
print("The True positive of cucumber is : ",cucutp)
print("The True positive of onion is : ",otp)
print("The True positive of pepper is : ",ptp)
print("The True positive of tapioca is : ",ttp)
# Out:
# <ipython-input-3-99d92f0df6e7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["season"][40]=data2["season"][i]
# <ipython-input-3-99d92f0df6e7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["pH"][40]=data2["pH"][i]
# <ipython-input-3-99d92f0df6e7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["soil_type"][40]=data2["soil_type"][i]
# <ipython-input-3-99d92f0df6e7>:6: SettingWithCopyWarning:
# ...

# %%
print("The True positive of carrot is : ",ctp)
print("The True positive of chilli is : ",chitp)
print("The True positive of cucumber is : ",cucutp)
print("The True positive of onion is : ",otp)
print("The True positive of pepper is : ",ptp)
print("The True positive of tapioca is : ",ttp)
#print("The total number of false prediction is : ",falsePrediction)
# Out:
# The True positive of carrot is :  19
# The True positive of chilli is :  15
# The True positive of cucumber is :  25
# The True positive of onion is :  25
# The True positive of pepper is :  22
# The True positive of tapioca is :  38

# %%
print("The total number of queries : ",df7.shape[0])
acc=(ctp+chitp+cucutp+otp+ptp+ttp)
print("Number of correct prediction : ",acc)
print("The Accuracy = ",acc/df7.shape[0]*100,"%")
# Out:
# The total number of queries :  145
# Number of correct prediction :  144
# The Accuracy =  99.3103448275862 %
